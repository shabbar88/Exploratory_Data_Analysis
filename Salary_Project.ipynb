# %% [markdown]
# <a href="https://colab.research.google.com/github/shabbar88/Exploratory_Data_Analysis/blob/main/Salary_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries and loading dataset
import numpy as np
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/shabbar88/LATEST-DATA--SCIENCE/refs/heads/main/Salaries.csv")

# %%
data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # 1.  Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# # 2. Check Last 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (148654, 13)

# %% [markdown]
# # 4.  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And  Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# # 5. Check Null Values In The Dataset

# %%
data.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# # 6. Drop ID, Notes, Agency, and Status Columns

# %%
data=data.drop(['Id','Notes','Agency','Status'],axis=1)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 7. Get Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448840    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %% [markdown]
# # 8. Find Occurrence of The Top 5 Employee Names

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
# Count occurrences of each employee name
name_counts = data['EmployeeName'].value_counts()
name_counts
# Out:
# EmployeeName
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: count, Length: 110811, dtype: int64

# %%
name_counts.head(5)
#  we cam achieve top 5 using this approach as well
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
# Get the top 5 names
top_5_names = name_counts.nlargest(5)

print(top_5_names)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# # 9. Find The Number of Unique Job Titles

# %%
uniq_job=data['JobTitle'].nunique()
print("Total number of unique Job Tile is {}".format(uniq_job))
# Out:
# Total number of unique Job Tile is 2159

# %% [markdown]
# # 10.Total Number of Job Titles Contain Captain

# %%
captain_count=len(data[data['JobTitle'].str.contains('CAPTAIN',case=False)])
print("Total Number of Job Titles Containing Captain is {}".format(captain_count))
# Out:
# Total Number of Job Titles Containing Captain is 552

# %% [markdown]
# # 11. Display All the Employee Names From Fire Department

# %%
fire_data=data[data['JobTitle'].str.contains('Fire',case=False)]['EmployeeName']
fire_data
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
list1=[x for x in fire_data]

# %%
print("List of Employees in Fire Dept are: {}".format(list1))
# Out:
# List of Employees in Fire Dept are: ['PATRICK GARDNER', 'ALSON LEE', 'MICHAEL MORRIS', 'JOANNE HAYES-WHITE', 'ARTHUR KENNEY', 'DAVID FRANKLIN', 'MARTY ROSS', 'GEORGE GARCIA', 'VICTOR WYRSCH', 'JOSEPH DRISCOLL', 'JOHN HANLEY', 'RAYMOND GUZMAN', 'MONICA FIELDS', 'JOSE VELO', 'BRENDAN WARD', 'MICHAEL THOMPSON', 'THOMAS ABBOTT', 'THOMAS SIRAGUSA', 'MICHAEL THOMPSON', 'BRYAN RUBENSTEIN', 'KEN YEE', 'KIRK RICHARDSON', 'MICHAEL ROLOVICH', 'DARRYL HUNTER', 'KENNETH SMITH', 'CHARLES CRANE', 'ROBERT POSTEL', 'EDWARD ROLAND', 'RICHARD BUSALACCHI', 'KEVIN BURKE', 'BERT REYES', 'MICHAEL DELANE', 'EDUARDO GONZALEZ', 'ROBERT WINSLOW', 'LORRIE KALOS', 'JONATHAN BAXTER', 'MICHAEL BRYANT', 'MARY TSE', 'MARK GONZALES', 'PETE FAY JR', 'REX HALE', 'KEVIN SMITH', 'GREGORY STANGLAND', 'KEVIN TAYLOR', 'ERIKA HOO', 'LAUIFI SEUMAALA', 'PATRIC STEELE', 'MICHAEL WALSH', 'SAMSON LAI', 'SCOTT SCHOLZEN', 'KHAIRUL ALI', 'MICHAEL CASTAGNOLA', 'SEAN BONETTI', 'JOHN HICKEY', 'GLEN KOJIMOTO', 'EDWARD CHU', 'SOFIA MATHE
# ...

# %%
len(list1)
# Out:
# 5879

# %% [markdown]
# # 12. Find Minimum, Maximum, and Average BasePay

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %%
data['BasePay'].min()
# Out:
# -166.01

# %%
data['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# # 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
# Replace 'Not Provided' with NaN
data['EmployeeName'] = data['EmployeeName'].replace('Not Provided', np.nan)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 14. Drop The Rows Having 4 Missing Values

# %%
len(data.columns)
# Out:
# 9

# %%
# data.dropna(thresh=len(data.columns) - 1)

# %%
# rows having 5 missing values
data[data.isnull().sum(axis=1)==4]
# Out:
#         EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 148646  Not provided  Not provided      NaN          NaN       NaN       NaN
# 148650  Not provided  Not provided      NaN          NaN       NaN       NaN
# 148651  Not provided  Not provided      NaN          NaN       NaN       NaN
# 148652  Not provided  Not provided      NaN          NaN       NaN       NaN
#
#         TotalPay  TotalPayBenefits  Year
# 148646       0.0               0.0  2014
# 148650       0.0               0.0  2014
# 148651       0.0               0.0  2014
# 148652       0.0               0.0  2014

# %%
data.drop(data[data.isnull().sum(axis=1)==4].index,axis=0,inplace=True)

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 15. Find Job Title of ALBERT PARDINI

# %%
name=data[data['EmployeeName']=='ALBERT PARDINI']['JobTitle']
name1 = [x for x in name]

# %%
print("Job Tiitle of ALBERT PARIDINI is {}".format(name1))
# Out:
# Job Tiitle of ALBERT PARIDINI is ['CAPTAIN III (POLICE DEPARTMENT)']

# %% [markdown]
# # 16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %% [markdown]
# # 16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
my_data=data[data['EmployeeName']=='ALBERT PARDINI']['TotalPayBenefits']

# %%
type(my_data)
# Out:
# pandas.core.series.Series

# %%
my_data.values
# Out:
# array([335279.91])

# %%
print("ALBERT PARDINI make {}".format(my_data.values))
# Out:
# ALBERT PARDINI make [335279.91]

# %% [markdown]
# # 17.Display Name of The Person Having The Highest BasePay

# %%
data[data['EmployeeName']==data['BasePay'].max()]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
highest_basepay_name = data.loc[data['BasePay'].idxmax(), 'EmployeeName']

print("The person with the highest BasePay is: {}".format(highest_basepay_name))
# Out:
# The person with the highest BasePay is: Gregory P Suhr

# %% [markdown]
# # 18.Find Average BasePay of All Employee Per Year

# %%
average_basepay_per_year = data.groupby('Year')['BasePay'].mean().reset_index()

print(average_basepay_per_year)
# Out:
#    Year       BasePay
# 0  2011  63595.956517
# 1  2012  65436.406857
# 2  2013  69630.030216
# 3  2014  66564.421924

# %% [markdown]
# # 19. Find Average BasePay of All Employee Per JobTitle

# %%
average_basepay_per_jobtitle = data.groupby('JobTitle')['BasePay'].mean().reset_index()

print(average_basepay_per_jobtitle)
# Out:
#                                             JobTitle       BasePay
# 0                                      ACCOUNT CLERK  43300.806506
# 1                                         ACCOUNTANT  46643.172000
# 2                                  ACCOUNTANT INTERN  28732.663958
# 3                        ACPO,JuvP, Juv Prob (SFERS)  62290.780000
# 4                                      ACUPUNCTURIST  66374.400000
# ...                                              ...           ...
# 2153                           X-RAY LABORATORY AIDE  47664.773077
# 2154                           X-Ray Laboratory Aide  46086.387100
# 2155  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000
# 2156                              Youth Comm Advisor  39077.957500
# 2157                                     ZOO CURATOR  43148.000000
#
# [2158 rows x 2 columns]

# %% [markdown]
# # 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
# Filter for employees with the job title ACCOUNTANT
accountants = data[data['JobTitle'] == 'ACCOUNTANT']

# Calculate the average BasePay
average_basepay_accountant = accountants['BasePay'].mean()

print(f"The average BasePay of employees with the job title ACCOUNTANT is: {average_basepay_accountant}")
# Out:
# The average BasePay of employees with the job title ACCOUNTANT is: 46643.172

# %% [markdown]
# # 21. Find Top 5 Most Common Jobs

# %%
top_jobs = data['JobTitle'].value_counts().head(5)

print(top_jobs)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148645   Carolyn A Wilson                       Human Services Technician
# 148647     Joann Anderson                     Communications Dispatcher 2
# 148648        Leon Walker                                       Custodian
# 148649      Roy I Tillery                                       Custodian
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...
